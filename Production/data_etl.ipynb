# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib notebook

# %% [markdown]
# ## Cleaned Data

# %%
# Read the csv file into a pandas DataFrame

all_wells = pd.read_csv('Cleaned_Data/all_wells.csv')
all_wells.head()
# Out:
#    Unnamed: 0    DATEPRD  WELL_BORE_CODE  AVG_DOWNHOLE_PRESSURE  \
# 0        8027  16-Jan-14  NO 15/9-F-15 D                241.771
# 1        8028  17-Jan-14  NO 15/9-F-15 D                213.852
# 2        8029  18-Jan-14  NO 15/9-F-15 D                206.615
# 3        8030  19-Jan-14  NO 15/9-F-15 D                203.075
# 4        8031  20-Jan-14  NO 15/9-F-15 D                203.981
#
#    AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  AVG_ANNULUS_PRESS  \
# 0                   104.899         185.90              19.06
# 1                   106.293         162.21              19.87
# 2                   106.375         157.93              27.81
# 3                   106.392         156.51              25.72
# 4                   106.317         157.11              12.03
#
#    AVG_CHOKE_SIZE_P  AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  BORE_OIL_VOL  \
# 0              8.66      55.87      16.90          27.97        351.05
# ...

# %%
all_wells.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7361 entries, 0 to 7360
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                7361 non-null   int64
#  1   DATEPRD                   7361 non-null   object
#  2   WELL_BORE_CODE            7361 non-null   object
#  3   AVG_DOWNHOLE_PRESSURE     7361 non-null   float64
#  4   AVG_DOWNHOLE_TEMPERATURE  7361 non-null   float64
#  5   AVG_DP_TUBING             7361 non-null   float64
#  6   AVG_ANNULUS_PRESS         6932 non-null   float64
#  7   AVG_CHOKE_SIZE_P          7361 non-null   float64
#  8   AVG_WHP_P                 7361 non-null   float64
#  9   AVG_WHT_P                 7361 non-null   float64
#  10  DP_CHOKE_SIZE             7361 non-null   float64
#  11  BORE_OIL_VOL              7361 non-null   float64
#  12  BORE_GAS_VOL              7361 non-null   float64
# ...

# %%
discovery_wells = pd.read_csv('Cleaned_Data/discovery_wells.csv')
discovery_wells.head()
# Out:
#    Unnamed: 0    DATEPRD  WELL_BORE_CODE  AVG_DOWNHOLE_PRESSURE  \
# 0           0  13-Jul-08  NO 15/9-F-14 H                260.867
# 1           1  14-Jul-08  NO 15/9-F-14 H                256.248
# 2           2  15-Jul-08  NO 15/9-F-14 H                254.983
# 3           3  16-Jul-08  NO 15/9-F-14 H                251.476
# 4           4  17-Jul-08  NO 15/9-F-14 H                249.346
#
#    AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  AVG_ANNULUS_PRESS  \
# 0                   103.293         160.15                0.0
# 1                   104.018         156.65                0.0
# 2                   103.967         156.33                0.0
# 3                   104.211         155.82                0.0
# 4                   104.339         155.76                0.0
#
#    AVG_CHOKE_SIZE_P  AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  BORE_OIL_VOL  \
# 0             21.05     100.71      52.38          69.54       1735.26
# ...

# %%
discovery_wells.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5044 entries, 0 to 5043
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                5044 non-null   int64
#  1   DATEPRD                   5044 non-null   object
#  2   WELL_BORE_CODE            5044 non-null   object
#  3   AVG_DOWNHOLE_PRESSURE     5044 non-null   float64
#  4   AVG_DOWNHOLE_TEMPERATURE  5044 non-null   float64
#  5   AVG_DP_TUBING             5044 non-null   float64
#  6   AVG_ANNULUS_PRESS         5044 non-null   float64
#  7   AVG_CHOKE_SIZE_P          5044 non-null   float64
#  8   AVG_WHP_P                 5044 non-null   float64
#  9   AVG_WHT_P                 5044 non-null   float64
#  10  DP_CHOKE_SIZE             5044 non-null   float64
#  11  BORE_OIL_VOL              5044 non-null   float64
#  12  BORE_GAS_VOL              5044 non-null   float64
# ...

# %%
appraisal_wells = pd.read_csv('Cleaned_Data/appraisal_wells.csv')
appraisal_wells.head()
# Out:
#    Unnamed: 0    DATEPRD  WELL_BORE_CODE  AVG_DOWNHOLE_PRESSURE  \
# 0           0  16-Jan-14  NO 15/9-F-15 D                241.771
# 1           1  17-Jan-14  NO 15/9-F-15 D                213.852
# 2           2  18-Jan-14  NO 15/9-F-15 D                206.615
# 3           3  19-Jan-14  NO 15/9-F-15 D                203.075
# 4           4  20-Jan-14  NO 15/9-F-15 D                203.981
#
#    AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  AVG_ANNULUS_PRESS  \
# 0                   104.899         185.90              19.06
# 1                   106.293         162.21              19.87
# 2                   106.375         157.93              27.81
# 3                   106.392         156.51              25.72
# 4                   106.317         157.11              12.03
#
#    AVG_CHOKE_SIZE_P  AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  BORE_OIL_VOL  \
# 0              8.66      55.87      16.90          27.97        351.05
# ...

# %%
appraisal_wells.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2317 entries, 0 to 2316
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                2317 non-null   int64
#  1   DATEPRD                   2317 non-null   object
#  2   WELL_BORE_CODE            2317 non-null   object
#  3   AVG_DOWNHOLE_PRESSURE     2317 non-null   float64
#  4   AVG_DOWNHOLE_TEMPERATURE  2317 non-null   float64
#  5   AVG_DP_TUBING             2317 non-null   float64
#  6   AVG_ANNULUS_PRESS         1888 non-null   float64
#  7   AVG_CHOKE_SIZE_P          2317 non-null   float64
#  8   AVG_WHP_P                 2317 non-null   float64
#  9   AVG_WHT_P                 2317 non-null   float64
#  10  DP_CHOKE_SIZE             2317 non-null   float64
#  11  BORE_OIL_VOL              2317 non-null   float64
#  12  BORE_GAS_VOL              2317 non-null   float64
# ...

# %%
appraisal_wells = pd.concat([Well_F15, Well_F11,Well_F1], ignore_index=True, sort =False)
appraisal_wells
# Out:
#         DATEPRD  WELL_BORE_CODE  AVG_DOWNHOLE_PRESSURE  \
# 0     16-Jan-14  NO 15/9-F-15 D                241.771
# 1     17-Jan-14  NO 15/9-F-15 D                213.852
# 2     18-Jan-14  NO 15/9-F-15 D                206.615
# 3     19-Jan-14  NO 15/9-F-15 D                203.075
# 4     20-Jan-14  NO 15/9-F-15 D                203.981
# ...         ...             ...                    ...
# 2312  02-Apr-16   NO 15/9-F-1 C                223.012
# 2313  03-Apr-16   NO 15/9-F-1 C                221.813
# 2314  04-Apr-16   NO 15/9-F-1 C                220.780
# 2315  05-Apr-16   NO 15/9-F-1 C                218.752
# 2316  06-Apr-16   NO 15/9-F-1 C                218.438
#
#       AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  AVG_ANNULUS_PRESS  \
# 0                      104.899         185.90              19.06
# 1                      106.293         162.21              19.87
# 2                      106.375         157.93              27.81
# ...

# %%
appraisal_wells.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2317 entries, 0 to 2316
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   2317 non-null   object
#  1   WELL_BORE_CODE            2317 non-null   object
#  2   AVG_DOWNHOLE_PRESSURE     2317 non-null   float64
#  3   AVG_DOWNHOLE_TEMPERATURE  2317 non-null   float64
#  4   AVG_DP_TUBING             2317 non-null   float64
#  5   AVG_ANNULUS_PRESS         1888 non-null   float64
#  6   AVG_CHOKE_SIZE_P          2317 non-null   float64
#  7   AVG_WHP_P                 2317 non-null   float64
#  8   AVG_WHT_P                 2317 non-null   float64
#  9   DP_CHOKE_SIZE             2317 non-null   float64
#  10  BORE_OIL_VOL              2317 non-null   float64
#  11  BORE_GAS_VOL              2317 non-null   float64
#  12  BORE_WAT_VOL              2317 non-null   float64
# dtypes: float64(11), object(2)
# ...

# %%
allWell_df.to_csv('all_wells.csv')

# %% [markdown]
# ## Exploratory Data Analysis (EDA) process

# %% [markdown]
# Pair Plots to see relationship between each columns

# %%
import seaborn as sns

#make pairplots
sns_plot1=sns.pairplot(all_wells, vars = ["AVG_DOWNHOLE_PRESSURE", "AVG_DOWNHOLE_TEMPERATURE", "AVG_DP_TUBING", "AVG_ANNULUS_PRESS",
                                 "AVG_CHOKE_SIZE_P","AVG_WHP_P","AVG_WHT_P"], hue="WELL_BORE_CODE")
# Out:
# C:\Users\sruth\Anaconda3\envs\mlproject\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns_plot1.savefig("all_well.png")

# %%
# Drop zero values in Average Downhole pressure
all_wells_drop_zero =all_wells[all_wells['AVG_DOWNHOLE_PRESSURE'] !=0]

# %%
all_wells_drop_zero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5450 entries, 0 to 7360
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                5450 non-null   int64
#  1   DATEPRD                   5450 non-null   object
#  2   WELL_BORE_CODE            5450 non-null   object
#  3   AVG_DOWNHOLE_PRESSURE     5450 non-null   float64
#  4   AVG_DOWNHOLE_TEMPERATURE  5450 non-null   float64
#  5   AVG_DP_TUBING             5450 non-null   float64
#  6   AVG_ANNULUS_PRESS         5021 non-null   float64
#  7   AVG_CHOKE_SIZE_P          5450 non-null   float64
#  8   AVG_WHP_P                 5450 non-null   float64
#  9   AVG_WHT_P                 5450 non-null   float64
#  10  DP_CHOKE_SIZE             5450 non-null   float64
#  11  BORE_OIL_VOL              5450 non-null   float64
#  12  BORE_GAS_VOL              5450 non-null   float64
# ...

# %%
all_wells_drop_zero.astype(bool).sum(axis=0)
# Out:
# Unnamed: 0                  5450
# DATEPRD                     5450
# WELL_BORE_CODE              5450
# AVG_DOWNHOLE_PRESSURE       5450
# AVG_DOWNHOLE_TEMPERATURE    5450
# AVG_DP_TUBING               5450
# AVG_ANNULUS_PRESS           4595
# AVG_CHOKE_SIZE_P            5450
# AVG_WHP_P                   5448
# AVG_WHT_P                   5450
# DP_CHOKE_SIZE               5450
# BORE_OIL_VOL                5448
# BORE_GAS_VOL                5450
# BORE_WAT_VOL                5081
# dtype: int64

# %%
#make pairplots
sns_plot1a=sns.pairplot(all_wells_drop_zero, vars = ["AVG_DOWNHOLE_PRESSURE", "AVG_DOWNHOLE_TEMPERATURE", "AVG_DP_TUBING", "AVG_ANNULUS_PRESS",
                                 "AVG_CHOKE_SIZE_P","AVG_WHP_P","AVG_WHT_P"], hue="WELL_BORE_CODE")
# Out:
# C:\Users\sruth\Anaconda3\envs\mlproject\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns_plot1a.savefig("all_well_new.png")

# %%
#Crest Wells
sns_plot2=sns.pairplot(discovery_wells, vars = ["AVG_DOWNHOLE_PRESSURE", "AVG_DOWNHOLE_TEMPERATURE", "AVG_DP_TUBING", "AVG_ANNULUS_PRESS",
                                 "AVG_CHOKE_SIZE_P","AVG_WHP_P","AVG_WHT_P"], hue="WELL_BORE_CODE")

# %%
sns_plot2.savefig("discovery_well.png")

# %%
discovery_wells_drop_zero =discovery_wells[discovery_wells['AVG_DOWNHOLE_PRESSURE'] !=0]

# %%
discovery_wells_drop_zero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3135 entries, 0 to 3136
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                3135 non-null   int64
#  1   DATEPRD                   3135 non-null   object
#  2   WELL_BORE_CODE            3135 non-null   object
#  3   AVG_DOWNHOLE_PRESSURE     3135 non-null   float64
#  4   AVG_DOWNHOLE_TEMPERATURE  3135 non-null   float64
#  5   AVG_DP_TUBING             3135 non-null   float64
#  6   AVG_ANNULUS_PRESS         3135 non-null   float64
#  7   AVG_CHOKE_SIZE_P          3135 non-null   float64
#  8   AVG_WHP_P                 3135 non-null   float64
#  9   AVG_WHT_P                 3135 non-null   float64
#  10  DP_CHOKE_SIZE             3135 non-null   float64
#  11  BORE_OIL_VOL              3135 non-null   float64
#  12  BORE_GAS_VOL              3135 non-null   float64
# ...

# %%
discovery_wells_drop_zero.astype(bool).sum(axis=0)
# Out:
# Unnamed: 0                  3134
# DATEPRD                     3135
# WELL_BORE_CODE              3135
# AVG_DOWNHOLE_PRESSURE       3135
# AVG_DOWNHOLE_TEMPERATURE    3135
# AVG_DP_TUBING               3135
# AVG_ANNULUS_PRESS           2284
# AVG_CHOKE_SIZE_P            3135
# AVG_WHP_P                   3133
# AVG_WHT_P                   3135
# DP_CHOKE_SIZE               3135
# BORE_OIL_VOL                3133
# BORE_GAS_VOL                3135
# BORE_WAT_VOL                3058
# dtype: int64

# %%
#Crest Wells drop_zero
sns_plot2a=sns.pairplot(discovery_wells_drop_zero, vars = ["AVG_DOWNHOLE_PRESSURE", "AVG_DOWNHOLE_TEMPERATURE", "AVG_DP_TUBING", "AVG_ANNULUS_PRESS",
                                 "AVG_CHOKE_SIZE_P","AVG_WHP_P","AVG_WHT_P"], hue="WELL_BORE_CODE")

# %%
sns_plot2a.savefig("discovery_well_new.png")

# %%
#Flank Wells
sns_plot3=sns.pairplot(appraisal_wells, vars = ["AVG_DOWNHOLE_PRESSURE", "AVG_DOWNHOLE_TEMPERATURE", "AVG_DP_TUBING", "AVG_ANNULUS_PRESS",
                                 "AVG_CHOKE_SIZE_P","AVG_WHP_P","AVG_WHT_P"], hue="WELL_BORE_CODE")
# Out:
# C:\Users\sruth\Anaconda3\envs\mlproject\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns_plot3.savefig("appraisal_wells.png")

# %%
new_all_well_non_zero =all_wells_drop_zero[all_wells_drop_zero['AVG_ANNULUS_PRESS'] !=0]

# %%
new_all_well_non_zero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4595 entries, 0 to 7360
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                4595 non-null   int64
#  1   DATEPRD                   4595 non-null   object
#  2   WELL_BORE_CODE            4595 non-null   object
#  3   AVG_DOWNHOLE_PRESSURE     4595 non-null   float64
#  4   AVG_DOWNHOLE_TEMPERATURE  4595 non-null   float64
#  5   AVG_DP_TUBING             4595 non-null   float64
#  6   AVG_ANNULUS_PRESS         4166 non-null   float64
#  7   AVG_CHOKE_SIZE_P          4595 non-null   float64
#  8   AVG_WHP_P                 4595 non-null   float64
#  9   AVG_WHT_P                 4595 non-null   float64
#  10  DP_CHOKE_SIZE             4595 non-null   float64
#  11  BORE_OIL_VOL              4595 non-null   float64
#  12  BORE_GAS_VOL              4595 non-null   float64
# ...

# %%
sns_plot4=sns.pairplot(new_all_well_non_zero, vars = ["AVG_DOWNHOLE_PRESSURE", "AVG_DOWNHOLE_TEMPERATURE", "AVG_DP_TUBING", "AVG_ANNULUS_PRESS",
                                 "AVG_CHOKE_SIZE_P","AVG_WHP_P","AVG_WHT_P"], hue="WELL_BORE_CODE")

# %%
sns_plot4.savefig("all_well_non_zero.png")
