# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib notebook

# %%
# Read the csv file into a pandas DataFrame

production = pd.read_csv('Data/Volve production data_original.csv')
production.head()
# Out:
#      DATEPRD WELL_BORE_CODE  AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  \
# 0  07-Apr-14  NO 15/9-F-1 C                  0.000                     0.000
# 1  08-Apr-14  NO 15/9-F-1 C                    NaN                       NaN
# 2  09-Apr-14  NO 15/9-F-1 C                    NaN                       NaN
# 3  10-Apr-14  NO 15/9-F-1 C                    NaN                       NaN
# 4  11-Apr-14  NO 15/9-F-1 C                310.376                    96.876
#
#    AVG_DP_TUBING  AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P  AVG_WHP_P  AVG_WHT_P  \
# 0           0.00                0.0              0.00        0.0       0.00
# 1            NaN                0.0              1.00        0.0       0.00
# 2            NaN                0.0              0.98        0.0       0.00
# 3            NaN                0.0              0.55        0.0       0.00
# 4         277.28                0.0              1.22       33.1      10.48
#
# ...

# %%
production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15634 entries, 0 to 15633
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   15634 non-null  object
#  1   WELL_BORE_CODE            15634 non-null  object
#  2   AVG_DOWNHOLE_PRESSURE     8980 non-null   float64
#  3   AVG_DOWNHOLE_TEMPERATURE  8980 non-null   float64
#  4   AVG_DP_TUBING             8980 non-null   float64
#  5   AVG_ANNULUS_PRESS         7890 non-null   float64
#  6   AVG_CHOKE_SIZE_P          8919 non-null   float64
#  7   AVG_WHP_P                 9155 non-null   float64
#  8   AVG_WHT_P                 9146 non-null   float64
#  9   DP_CHOKE_SIZE             15340 non-null  float64
#  10  BORE_OIL_VOL              9161 non-null   float64
#  11  BORE_GAS_VOL              9161 non-null   float64
#  12  BORE_WAT_VOL              9161 non-null   float64
# dtypes: float64(11), object(2)
# ...

# %%
production['WELL_BORE_CODE'].value_counts()
# Out:
# NO 15/9-F-4 AH    3327
# NO 15/9-F-5 AH    3306
# NO 15/9-F-14 H    3056
# NO 15/9-F-12 H    3056
# NO 15/9-F-11 H    1165
# NO 15/9-F-15 D     978
# NO 15/9-F-1 C      746
# Name: WELL_BORE_CODE, dtype: int64

# %% [markdown]
# ## NO 15/9-F-5 AH

# %%
# NO 15/9-F-4 AH - no data
# NO 15/9-F-5 AH - only data for 
# AVG_ANNULUS_PRESS	AVG_CHOKE_SIZE_P,AVG_WHP_P	AVG_WHT_P	DP_CHOKE_SIZE	BORE_OIL_VOL	BORE_GAS_VOL	BORE_WAT_VOL
Well_F5 = production.loc[production['WELL_BORE_CODE']=='NO 15/9-F-5 AH']
Well_F5
# Out:
#          DATEPRD  WELL_BORE_CODE  AVG_DOWNHOLE_PRESSURE  \
# 12328  01-Sep-07  NO 15/9-F-5 AH                    NaN
# 12329  02-Sep-07  NO 15/9-F-5 AH                    NaN
# 12330  03-Sep-07  NO 15/9-F-5 AH                    NaN
# 12331  04-Sep-07  NO 15/9-F-5 AH                    NaN
# 12332  05-Sep-07  NO 15/9-F-5 AH                    NaN
# ...          ...             ...                    ...
# 15629  14-Sep-16  NO 15/9-F-5 AH                    NaN
# 15630  15-Sep-16  NO 15/9-F-5 AH                    NaN
# 15631  16-Sep-16  NO 15/9-F-5 AH                    NaN
# 15632  17-Sep-16  NO 15/9-F-5 AH                    NaN
# 15633  18-Sep-16  NO 15/9-F-5 AH                    NaN
#
#        AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  AVG_ANNULUS_PRESS  \
# 12328                       NaN            NaN                NaN
# 12329                       NaN            NaN                NaN
# 12330                       NaN            NaN                NaN
# ...

# %%
Well_F5=Well_F5.drop(columns= ['AVG_DOWNHOLE_PRESSURE','AVG_DOWNHOLE_TEMPERATURE','AVG_DP_TUBING'])

# %%
Well_F5=Well_F5.dropna()

# %%
Well_F5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 15482 to 15632
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   DATEPRD            151 non-null    object
#  1   WELL_BORE_CODE     151 non-null    object
#  2   AVG_ANNULUS_PRESS  151 non-null    float64
#  3   AVG_CHOKE_SIZE_P   151 non-null    float64
#  4   AVG_WHP_P          151 non-null    float64
#  5   AVG_WHT_P          151 non-null    float64
#  6   DP_CHOKE_SIZE      151 non-null    float64
#  7   BORE_OIL_VOL       151 non-null    float64
#  8   BORE_GAS_VOL       151 non-null    float64
#  9   BORE_WAT_VOL       151 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 13.0+ KB

# %%
y1= Well_F5["BORE_OIL_VOL"].values.reshape(-1, 1)
X1=Well_F5["AVG_ANNULUS_PRESS"].values.reshape(-1, 1)
X2=Well_F5["AVG_CHOKE_SIZE_P"].values.reshape(-1, 1)
X3=Well_F5["AVG_WHP_P"].values.reshape(-1, 1)
X4=Well_F5["AVG_WHT_P"].values.reshape(-1, 1)
X5=Well_F5["DP_CHOKE_SIZE"].values.reshape(-1, 1)

# %%
# plt.scatter(X1, y1)
# plt.xlabel("AVG_ANNULUS_PRESS")
# plt.ylabel("Oil Volume")

# %%
# plt.scatter(X2, y1)
# plt.xlabel("Avg Choke Size")
# plt.ylabel("Oil Volume")

# %%
# plt.scatter(X3, y1)
# plt.xlabel("Avg WHP")
# plt.ylabel("Oil Volume")

# %%
# plt.scatter(X4, y1)
# plt.xlabel("Avg WH Temp")
# plt.ylabel("Oil Volume")

# %%
plt.scatter(X1, y1)
plt.xlabel("AVG_ANNULUS_PRESS")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X2, y1)
plt.xlabel("Avg Choke Size")
plt.ylabel("Oil Volume")
plt.show()


plt.scatter(X3, y1)
plt.xlabel("Avg WHP")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X5, y1)
plt.xlabel("DP Choke Size")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X4, y1)
plt.xlabel("Avg WH Temp")
plt.ylabel("Oil Volume")

plt.show()

# %%
# from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X1, y1, random_state=42)
# from sklearn.linear_model import LinearRegression
# model = LinearRegression()
# model.fit(X_train, y_train)
# plt.scatter(X_train, y_train, color'g')
# plt.plot(X_train,model.predict(model), color'r')
# plt.xlabel("AVG_ANNULUS_PRESS")
# plt.ylabel("Oil Volume")
# plt.title("Univariate Linear Regression")
# plt.show()

# %%
# testing_score=model.score(X_test, y_test)
# training_score=model.score(X_train, y_train)

# %% [markdown]
# ## Well NO 15/9-F-15 D

# %%
Well_F15 = production.loc[production['WELL_BORE_CODE']=='NO 15/9-F-15 D']
Well_F15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 978 entries, 8023 to 9000
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   978 non-null    object
#  1   WELL_BORE_CODE            978 non-null    object
#  2   AVG_DOWNHOLE_PRESSURE     978 non-null    float64
#  3   AVG_DOWNHOLE_TEMPERATURE  978 non-null    float64
#  4   AVG_DP_TUBING             978 non-null    float64
#  5   AVG_ANNULUS_PRESS         978 non-null    float64
#  6   AVG_CHOKE_SIZE_P          978 non-null    float64
#  7   AVG_WHP_P                 978 non-null    float64
#  8   AVG_WHT_P                 978 non-null    float64
#  9   DP_CHOKE_SIZE             978 non-null    float64
#  10  BORE_OIL_VOL              978 non-null    float64
#  11  BORE_GAS_VOL              978 non-null    float64
#  12  BORE_WAT_VOL              978 non-null    float64
# dtypes: float64(11), object(2)
# ...

# %%
Well_F15 =Well_F15.drop(Well_F15[(Well_F15['BORE_OIL_VOL'] == 0) & (Well_F15['BORE_GAS_VOL'] == 0.0) & (Well_F15['BORE_WAT_VOL'] == 0)].index)

# %%
Well_F15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 767 entries, 8027 to 8927
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   767 non-null    object
#  1   WELL_BORE_CODE            767 non-null    object
#  2   AVG_DOWNHOLE_PRESSURE     767 non-null    float64
#  3   AVG_DOWNHOLE_TEMPERATURE  767 non-null    float64
#  4   AVG_DP_TUBING             767 non-null    float64
#  5   AVG_ANNULUS_PRESS         767 non-null    float64
#  6   AVG_CHOKE_SIZE_P          767 non-null    float64
#  7   AVG_WHP_P                 767 non-null    float64
#  8   AVG_WHT_P                 767 non-null    float64
#  9   DP_CHOKE_SIZE             767 non-null    float64
#  10  BORE_OIL_VOL              767 non-null    float64
#  11  BORE_GAS_VOL              767 non-null    float64
#  12  BORE_WAT_VOL              767 non-null    float64
# dtypes: float64(11), object(2)
# ...

# %%
Well_F15.to_csv('F15.csv')

# %%
y1= Well_F15["BORE_OIL_VOL"].values.reshape(-1, 1)
X1=Well_F15["AVG_ANNULUS_PRESS"].values.reshape(-1, 1)
X2=Well_F15["AVG_CHOKE_SIZE_P"].values.reshape(-1, 1)
X3=Well_F15["AVG_WHP_P"].values.reshape(-1, 1)
X4=Well_F15["AVG_WHT_P"].values.reshape(-1, 1)
X5=Well_F15["DP_CHOKE_SIZE"].values.reshape(-1, 1)
X6=Well_F15["AVG_DOWNHOLE_PRESSURE"].values.reshape(-1, 1)
X7=Well_F15["AVG_DOWNHOLE_TEMPERATURE"].values.reshape(-1, 1)
X8=Well_F15["AVG_DP_TUBING"].values.reshape(-1, 1)

# %%
plt.scatter(X1, y1)
plt.xlabel("AVG_ANNULUS_PRESS")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X2, y1)
plt.xlabel("Avg Choke Size")
plt.ylabel("Oil Volume")
plt.show()


plt.scatter(X3, y1)
plt.xlabel("Avg WHP")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X4, y1)
plt.xlabel("Avg WH Temp")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X5, y1)
plt.xlabel("DP Choke Size")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X6, y1)
plt.xlabel("AVG_DOWNHOLE_PRESSURE")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X7, y1)
plt.xlabel("AVG_DOWNHOLE_TEMPERATURE  ")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X8, y1)
plt.xlabel("AVG_DP_TUBING")
plt.ylabel("Oil Volume")
plt.show()



plt.show()

# %%
y2= Well_F15["BORE_WAT_VOL"].values.reshape(-1, 1)
X1=Well_F15["AVG_ANNULUS_PRESS"].values.reshape(-1, 1)
X2=Well_F15["AVG_CHOKE_SIZE_P"].values.reshape(-1, 1)
X3=Well_F15["AVG_WHP_P"].values.reshape(-1, 1)
X4=Well_F15["AVG_WHT_P"].values.reshape(-1, 1)
X5=Well_F15["DP_CHOKE_SIZE"].values.reshape(-1, 1)
X6=Well_F15["AVG_DOWNHOLE_PRESSURE"].values.reshape(-1, 1)
X7=Well_F15["AVG_DOWNHOLE_TEMPERATURE"].values.reshape(-1, 1)
X8=Well_F15["AVG_DP_TUBING"].values.reshape(-1, 1)

# %% [markdown]
# ## NO 15/9-F-14 H

# %%
Well_F14 = production.loc[production['WELL_BORE_CODE']=='NO 15/9-F-14 H']
Well_F14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3056 entries, 4967 to 8022
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   3056 non-null   object
#  1   WELL_BORE_CODE            3056 non-null   object
#  2   AVG_DOWNHOLE_PRESSURE     3050 non-null   float64
#  3   AVG_DOWNHOLE_TEMPERATURE  3050 non-null   float64
#  4   AVG_DP_TUBING             3050 non-null   float64
#  5   AVG_ANNULUS_PRESS         2533 non-null   float64
#  6   AVG_CHOKE_SIZE_P          2860 non-null   float64
#  7   AVG_WHP_P                 3056 non-null   float64
#  8   AVG_WHT_P                 3056 non-null   float64
#  9   DP_CHOKE_SIZE             3056 non-null   float64
#  10  BORE_OIL_VOL              3056 non-null   float64
#  11  BORE_GAS_VOL              3056 non-null   float64
#  12  BORE_WAT_VOL              3056 non-null   float64
# dtypes: float64(11), object(2)
# ...

# %%
Well_F14=Well_F14.dropna()
Well_F14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2360 entries, 5014 to 8022
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   2360 non-null   object
#  1   WELL_BORE_CODE            2360 non-null   object
#  2   AVG_DOWNHOLE_PRESSURE     2360 non-null   float64
#  3   AVG_DOWNHOLE_TEMPERATURE  2360 non-null   float64
#  4   AVG_DP_TUBING             2360 non-null   float64
#  5   AVG_ANNULUS_PRESS         2360 non-null   float64
#  6   AVG_CHOKE_SIZE_P          2360 non-null   float64
#  7   AVG_WHP_P                 2360 non-null   float64
#  8   AVG_WHT_P                 2360 non-null   float64
#  9   DP_CHOKE_SIZE             2360 non-null   float64
#  10  BORE_OIL_VOL              2360 non-null   float64
#  11  BORE_GAS_VOL              2360 non-null   float64
#  12  BORE_WAT_VOL              2360 non-null   float64
# dtypes: float64(11), object(2)
# ...

# %%
Well_F14 =Well_F14.drop(Well_F14[(Well_F14['BORE_OIL_VOL'] == 0) & (Well_F14['BORE_GAS_VOL'] == 0.0) & (Well_F14['BORE_WAT_VOL'] == 0)].index)
Well_F14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2225 entries, 5118 to 7956
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   2225 non-null   object
#  1   WELL_BORE_CODE            2225 non-null   object
#  2   AVG_DOWNHOLE_PRESSURE     2225 non-null   float64
#  3   AVG_DOWNHOLE_TEMPERATURE  2225 non-null   float64
#  4   AVG_DP_TUBING             2225 non-null   float64
#  5   AVG_ANNULUS_PRESS         2225 non-null   float64
#  6   AVG_CHOKE_SIZE_P          2225 non-null   float64
#  7   AVG_WHP_P                 2225 non-null   float64
#  8   AVG_WHT_P                 2225 non-null   float64
#  9   DP_CHOKE_SIZE             2225 non-null   float64
#  10  BORE_OIL_VOL              2225 non-null   float64
#  11  BORE_GAS_VOL              2225 non-null   float64
#  12  BORE_WAT_VOL              2225 non-null   float64
# dtypes: float64(11), object(2)
# ...

# %%
Well_F14.to_csv('F14.csv')

# %%
y1= Well_F14["BORE_OIL_VOL"].values.reshape(-1, 1)
X1=Well_F14["AVG_ANNULUS_PRESS"].values.reshape(-1, 1)
X2=Well_F14["AVG_CHOKE_SIZE_P"].values.reshape(-1, 1)
X3=Well_F14["AVG_WHP_P"].values.reshape(-1, 1)
X4=Well_F14["AVG_WHT_P"].values.reshape(-1, 1)
X5=Well_F14["DP_CHOKE_SIZE"].values.reshape(-1, 1)
X6=Well_F14["AVG_DOWNHOLE_PRESSURE"].values.reshape(-1, 1)
X7=Well_F14["AVG_DOWNHOLE_TEMPERATURE"].values.reshape(-1, 1)
X8=Well_F14["AVG_DP_TUBING"].values.reshape(-1, 1)
year = Well_F14['DATEPRD'].values.reshape(-1, 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X3, y1, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(X_train, y_train, color='g')
plt.plot(X_test,model.predict(X_test),color='r')
plt.xlabel("Avg WHP")
plt.ylabel("Oil Volume")
plt.show()

print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [[30.71452447]]
# y-axis intercept:  [-179.33380637]

# %%
plt.scatter(X1, y1)
plt.xlabel("AVG_ANNULUS_PRESS")
plt.ylabel("Oil Volume")

model.fit(X_train, y_train)
plt.scatter(X_train, y_train, color'g')
plt.plot(X_train,model.predict(model), color'r')
plt.show()

plt.scatter(X2, y1)
plt.xlabel("Avg Choke Size")
plt.ylabel("Oil Volume")
plt.show()


plt.scatter(X3, y1)
plt.xlabel("Avg WHP")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X4, y1)
plt.xlabel("Avg WH Temp")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X5, y1)
plt.xlabel("DP Choke Size")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X6, y1)
plt.xlabel("AVG_DOWNHOLE_PRESSURE")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X7, y1)
plt.xlabel("AVG_DOWNHOLE_TEMPERATURE  ")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X8, y1)
plt.xlabel("AVG_DP_TUBING")
plt.ylabel("Oil Volume")
plt.show()

# %%
y2= Well_F14["BORE_OIL_VOL"].values.reshape(-1, 1)
X1=Well_F14["AVG_ANNULUS_PRESS"].values.reshape(-1, 1)
X2=Well_F14["AVG_CHOKE_SIZE_P"].values.reshape(-1, 1)
X3=Well_F14["AVG_WHP_P"].values.reshape(-1, 1)
X4=Well_F14["AVG_WHT_P"].values.reshape(-1, 1)
X5=Well_F14["DP_CHOKE_SIZE"].values.reshape(-1, 1)
X6=Well_F14["AVG_DOWNHOLE_PRESSURE"].values.reshape(-1, 1)
X7=Well_F14["AVG_DOWNHOLE_TEMPERATURE"].values.reshape(-1, 1)
X8=Well_F14["AVG_DP_TUBING"].values.reshape(-1, 1)

# %%
plt.scatter(X1, y2)
plt.xlabel("AVG_ANNULUS_PRESS")
plt.ylabel("Gas Volume")
plt.show()

plt.scatter(X2, y2)
plt.xlabel("Avg Choke Size")
plt.ylabel("Gas Volume")
plt.show()


plt.scatter(X3, y2)
plt.xlabel("Avg WHP")
plt.ylabel("Gas Volume")
plt.show()

plt.scatter(X4, y2)
plt.xlabel("Avg WH Temp")
plt.ylabel("Gas Volume")
plt.show()

plt.scatter(X5, y2)
plt.xlabel("DP Choke Size")
plt.ylabel("Gas Volume")
plt.show()

plt.scatter(X6, y2)
plt.xlabel("AVG_DOWNHOLE_PRESSURE")
plt.ylabel("Gas Volume")
plt.show()

plt.scatter(X7, y2)
plt.xlabel("AVG_DOWNHOLE_TEMPERATURE  ")
plt.ylabel("Gas Volume")
plt.show()

plt.scatter(X8, y2)
plt.xlabel("AVG_DP_TUBING")
plt.ylabel("Gas Volume")
plt.show()

# %%
y3= Well_F14["BORE_WAT_VOL"].values.reshape(-1, 1)
X1=Well_F14["AVG_ANNULUS_PRESS"].values.reshape(-1, 1)
X2=Well_F14["AVG_CHOKE_SIZE_P"].values.reshape(-1, 1)
X3=Well_F14["AVG_WHP_P"].values.reshape(-1, 1)
X4=Well_F14["AVG_WHT_P"].values.reshape(-1, 1)
X5=Well_F14["DP_CHOKE_SIZE"].values.reshape(-1, 1)
X6=Well_F14["AVG_DOWNHOLE_PRESSURE"].values.reshape(-1, 1)
X7=Well_F14["AVG_DOWNHOLE_TEMPERATURE"].values.reshape(-1, 1)
X8=Well_F14["AVG_DP_TUBING"].values.reshape(-1, 1)

# %%
plt.scatter(X1, y3)
plt.xlabel("AVG_ANNULUS_PRESS")
plt.ylabel("Water Volume")
plt.show()

plt.scatter(X2, y3)
plt.xlabel("Avg Choke Size")
plt.ylabel("Water Volume")
plt.show()


plt.scatter(X3, y3)
plt.xlabel("Avg WHP")
plt.ylabel("Water Volume")
plt.show()

plt.scatter(X4, y3)
plt.xlabel("Avg WH Temp")
plt.ylabel("Water Volume")
plt.show()

plt.scatter(X5, y3)
plt.xlabel("DP Choke Size")
plt.ylabel("Water Volume")
plt.show()

plt.scatter(X6, y3)
plt.xlabel("AVG_DOWNHOLE_PRESSURE")
plt.ylabel("Water Volume")
plt.show()

plt.scatter(X7, y3)
plt.xlabel("AVG_DOWNHOLE_TEMPERATURE  ")
plt.ylabel("Water Volume")
plt.show()

plt.scatter(X8, y3)
plt.xlabel("AVG_DP_TUBING")
plt.ylabel("Water Volume")
plt.show()

# %% [markdown]
# ## NO 15/9-F-12 H

# %%
Well_F12 = production.loc[production['WELL_BORE_CODE']=='NO 15/9-F-12 H']
Well_F12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3056 entries, 1911 to 4966
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   3056 non-null   object
#  1   WELL_BORE_CODE            3056 non-null   object
#  2   AVG_DOWNHOLE_PRESSURE     3050 non-null   float64
#  3   AVG_DOWNHOLE_TEMPERATURE  3050 non-null   float64
#  4   AVG_DP_TUBING             3050 non-null   float64
#  5   AVG_ANNULUS_PRESS         3043 non-null   float64
#  6   AVG_CHOKE_SIZE_P          3012 non-null   float64
#  7   AVG_WHP_P                 3056 non-null   float64
#  8   AVG_WHT_P                 3056 non-null   float64
#  9   DP_CHOKE_SIZE             3056 non-null   float64
#  10  BORE_OIL_VOL              3056 non-null   float64
#  11  BORE_GAS_VOL              3056 non-null   float64
#  12  BORE_WAT_VOL              3056 non-null   float64
# dtypes: float64(11), object(2)
# ...

# %%
Well_F12=Well_F12.dropna()
Well_F12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2993 entries, 1911 to 4966
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   2993 non-null   object
#  1   WELL_BORE_CODE            2993 non-null   object
#  2   AVG_DOWNHOLE_PRESSURE     2993 non-null   float64
#  3   AVG_DOWNHOLE_TEMPERATURE  2993 non-null   float64
#  4   AVG_DP_TUBING             2993 non-null   float64
#  5   AVG_ANNULUS_PRESS         2993 non-null   float64
#  6   AVG_CHOKE_SIZE_P          2993 non-null   float64
#  7   AVG_WHP_P                 2993 non-null   float64
#  8   AVG_WHT_P                 2993 non-null   float64
#  9   DP_CHOKE_SIZE             2993 non-null   float64
#  10  BORE_OIL_VOL              2993 non-null   float64
#  11  BORE_GAS_VOL              2993 non-null   float64
#  12  BORE_WAT_VOL              2993 non-null   float64
# dtypes: float64(11), object(2)
# ...

# %%
Well_F12 =Well_F12.drop(Well_F12[(Well_F12['BORE_OIL_VOL'] == 0) & (Well_F12['BORE_GAS_VOL'] == 0.0) & (Well_F12['BORE_WAT_VOL'] == 0)].index)
Well_F12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2819 entries, 1911 to 4930
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   2819 non-null   object
#  1   WELL_BORE_CODE            2819 non-null   object
#  2   AVG_DOWNHOLE_PRESSURE     2819 non-null   float64
#  3   AVG_DOWNHOLE_TEMPERATURE  2819 non-null   float64
#  4   AVG_DP_TUBING             2819 non-null   float64
#  5   AVG_ANNULUS_PRESS         2819 non-null   float64
#  6   AVG_CHOKE_SIZE_P          2819 non-null   float64
#  7   AVG_WHP_P                 2819 non-null   float64
#  8   AVG_WHT_P                 2819 non-null   float64
#  9   DP_CHOKE_SIZE             2819 non-null   float64
#  10  BORE_OIL_VOL              2819 non-null   float64
#  11  BORE_GAS_VOL              2819 non-null   float64
#  12  BORE_WAT_VOL              2819 non-null   float64
# dtypes: float64(11), object(2)
# ...

# %%
Well_F12.to_csv('F12.csv')

# %%
y1= Well_F12["BORE_OIL_VOL"].values.reshape(-1, 1)
X1=Well_F12["AVG_ANNULUS_PRESS"].values.reshape(-1, 1)
X2=Well_F12["AVG_CHOKE_SIZE_P"].values.reshape(-1, 1)
X3=Well_F12["AVG_WHP_P"].values.reshape(-1, 1)
X4=Well_F12["AVG_WHT_P"].values.reshape(-1, 1)
X5=Well_F12["DP_CHOKE_SIZE"].values.reshape(-1, 1)
X6=Well_F12["AVG_DOWNHOLE_PRESSURE"].values.reshape(-1, 1)
X7=Well_F12["AVG_DOWNHOLE_TEMPERATURE"].values.reshape(-1, 1)
X8=Well_F12["AVG_DP_TUBING"].values.reshape(-1, 1)

# %%
plt.scatter(X1, y1)
plt.xlabel("AVG_ANNULUS_PRESS")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X2, y1)
plt.xlabel("Avg Choke Size")
plt.ylabel("Oil Volume")
plt.show()


plt.scatter(X3, y1)
plt.xlabel("Avg WHP")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X4, y1)
plt.xlabel("Avg WH Temp")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X5, y1)
plt.xlabel("DP Choke Size")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X6, y1)
plt.xlabel("AVG_DOWNHOLE_PRESSURE")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X7, y1)
plt.xlabel("AVG_DOWNHOLE_TEMPERATURE  ")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X8, y1)
plt.xlabel("AVG_DP_TUBING")
plt.ylabel("Oil Volume")
plt.show()

# %%
y2= Well_F12["BORE_GAS_VOL"].values.reshape(-1, 1)
X1=Well_F12["AVG_ANNULUS_PRESS"].values.reshape(-1, 1)
X2=Well_F12["AVG_CHOKE_SIZE_P"].values.reshape(-1, 1)
X3=Well_F12["AVG_WHP_P"].values.reshape(-1, 1)
X4=Well_F12["AVG_WHT_P"].values.reshape(-1, 1)
X5=Well_F12["DP_CHOKE_SIZE"].values.reshape(-1, 1)
X6=Well_F12["AVG_DOWNHOLE_PRESSURE"].values.reshape(-1, 1)
X7=Well_F12["AVG_DOWNHOLE_TEMPERATURE"].values.reshape(-1, 1)
X8=Well_F12["AVG_DP_TUBING"].values.reshape(-1, 1)

# %%
plt.scatter(X1, y2)
plt.xlabel("AVG_ANNULUS_PRESS")
plt.ylabel("Gas Volume")
plt.show()

plt.scatter(X2, y2)
plt.xlabel("Avg Choke Size")
plt.ylabel("Gas Volume")
plt.show()


plt.scatter(X3, y2)
plt.xlabel("Avg WHP")
plt.ylabel("Gas Volume")
plt.show()

plt.scatter(X4, y2)
plt.xlabel("Avg WH Temp")
plt.ylabel("Gas Volume")
plt.show()

plt.scatter(X5, y2)
plt.xlabel("DP Choke Size")
plt.ylabel("Gas Volume")
plt.show()

plt.scatter(X6, y2)
plt.xlabel("AVG_DOWNHOLE_PRESSURE")
plt.ylabel("Gas Volume")
plt.show()

plt.scatter(X7, y2)
plt.xlabel("AVG_DOWNHOLE_TEMPERATURE  ")
plt.ylabel("Gas Volume")
plt.show()

plt.scatter(X8, y2)
plt.xlabel("AVG_DP_TUBING")
plt.ylabel("Gas Volume")
plt.show()

# %%
y3= Well_F12["BORE_WAT_VOL"].values.reshape(-1, 1)
X1=Well_F12["AVG_ANNULUS_PRESS"].values.reshape(-1, 1)
X2=Well_F12["AVG_CHOKE_SIZE_P"].values.reshape(-1, 1)
X3=Well_F12["AVG_WHP_P"].values.reshape(-1, 1)
X4=Well_F12["AVG_WHT_P"].values.reshape(-1, 1)
X5=Well_F12["DP_CHOKE_SIZE"].values.reshape(-1, 1)
X6=Well_F12["AVG_DOWNHOLE_PRESSURE"].values.reshape(-1, 1)
X7=Well_F12["AVG_DOWNHOLE_TEMPERATURE"].values.reshape(-1, 1)
X8=Well_F12["AVG_DP_TUBING"].values.reshape(-1, 1)

# %%
plt.scatter(X1, y3)
plt.xlabel("AVG_ANNULUS_PRESS")
plt.ylabel("Water Volume")
plt.show()

plt.scatter(X2, y3)
plt.xlabel("Avg Choke Size")
plt.ylabel("Water Volume")
plt.show()


plt.scatter(X3, y3)
plt.xlabel("Avg WHP")
plt.ylabel("Water Volume")
plt.show()

plt.scatter(X4, y3)
plt.xlabel("Avg WH Temp")
plt.ylabel("Water Volume")
plt.show()

plt.scatter(X5, y3)
plt.xlabel("DP Choke Size")
plt.ylabel("Water Volume")
plt.show()

plt.scatter(X6, y3)
plt.xlabel("AVG_DOWNHOLE_PRESSURE")
plt.ylabel("Water Volume")
plt.show()

plt.scatter(X7, y3)
plt.xlabel("AVG_DOWNHOLE_TEMPERATURE  ")
plt.ylabel("Water Volume")
plt.show()

plt.scatter(X8, y3)
plt.xlabel("AVG_DP_TUBING")
plt.ylabel("Water Volume")
plt.show()

# %% [markdown]
# ## NO 15/9-F-11 H

# %%
Well_F11 = production.loc[production['WELL_BORE_CODE']=='NO 15/9-F-11 H']
Well_F11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1165 entries, 746 to 1910
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   1165 non-null   object
#  1   WELL_BORE_CODE            1165 non-null   object
#  2   AVG_DOWNHOLE_PRESSURE     1159 non-null   float64
#  3   AVG_DOWNHOLE_TEMPERATURE  1159 non-null   float64
#  4   AVG_DP_TUBING             1159 non-null   float64
#  5   AVG_ANNULUS_PRESS         1159 non-null   float64
#  6   AVG_CHOKE_SIZE_P          1163 non-null   float64
#  7   AVG_WHP_P                 1159 non-null   float64
#  8   AVG_WHT_P                 1159 non-null   float64
#  9   DP_CHOKE_SIZE             1159 non-null   float64
#  10  BORE_OIL_VOL              1165 non-null   float64
#  11  BORE_GAS_VOL              1165 non-null   float64
#  12  BORE_WAT_VOL              1165 non-null   float64
# dtypes: float64(11), object(2)
# ...

# %%
Well_F11=Well_F11.dropna()
Well_F11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1159 entries, 746 to 1910
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   1159 non-null   object
#  1   WELL_BORE_CODE            1159 non-null   object
#  2   AVG_DOWNHOLE_PRESSURE     1159 non-null   float64
#  3   AVG_DOWNHOLE_TEMPERATURE  1159 non-null   float64
#  4   AVG_DP_TUBING             1159 non-null   float64
#  5   AVG_ANNULUS_PRESS         1159 non-null   float64
#  6   AVG_CHOKE_SIZE_P          1159 non-null   float64
#  7   AVG_WHP_P                 1159 non-null   float64
#  8   AVG_WHT_P                 1159 non-null   float64
#  9   DP_CHOKE_SIZE             1159 non-null   float64
#  10  BORE_OIL_VOL              1159 non-null   float64
#  11  BORE_GAS_VOL              1159 non-null   float64
#  12  BORE_WAT_VOL              1159 non-null   float64
# dtypes: float64(11), object(2)
# ...

# %%
Well_F11 =Well_F11.drop(Well_F11[(Well_F11['BORE_OIL_VOL'] == 0) & (Well_F11['BORE_GAS_VOL'] == 0.0) & (Well_F11['BORE_WAT_VOL'] == 0)].index)
Well_F11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1120 entries, 762 to 1910
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   1120 non-null   object
#  1   WELL_BORE_CODE            1120 non-null   object
#  2   AVG_DOWNHOLE_PRESSURE     1120 non-null   float64
#  3   AVG_DOWNHOLE_TEMPERATURE  1120 non-null   float64
#  4   AVG_DP_TUBING             1120 non-null   float64
#  5   AVG_ANNULUS_PRESS         1120 non-null   float64
#  6   AVG_CHOKE_SIZE_P          1120 non-null   float64
#  7   AVG_WHP_P                 1120 non-null   float64
#  8   AVG_WHT_P                 1120 non-null   float64
#  9   DP_CHOKE_SIZE             1120 non-null   float64
#  10  BORE_OIL_VOL              1120 non-null   float64
#  11  BORE_GAS_VOL              1120 non-null   float64
#  12  BORE_WAT_VOL              1120 non-null   float64
# dtypes: float64(11), object(2)
# ...

# %%
Well_F11.to_csv('F11.csv')

# %%
y1= Well_F11["BORE_OIL_VOL"].values.reshape(-1, 1)
X1=Well_F11["AVG_ANNULUS_PRESS"].values.reshape(-1, 1)
X2=Well_F11["AVG_CHOKE_SIZE_P"].values.reshape(-1, 1)
X3=Well_F11["AVG_WHP_P"].values.reshape(-1, 1)
X4=Well_F11["AVG_WHT_P"].values.reshape(-1, 1)
X5=Well_F11["DP_CHOKE_SIZE"].values.reshape(-1, 1)
X6=Well_F11["AVG_DOWNHOLE_PRESSURE"].values.reshape(-1, 1)
X7=Well_F11["AVG_DOWNHOLE_TEMPERATURE"].values.reshape(-1, 1)
X8=Well_F11["AVG_DP_TUBING"].values.reshape(-1, 1)

# %%
plt.scatter(X1, y1)
plt.xlabel("AVG_ANNULUS_PRESS")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X2, y1)
plt.xlabel("Avg Choke Size")
plt.ylabel("Oil Volume")
plt.show()


plt.scatter(X3, y1)
plt.xlabel("Avg WHP")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X4, y1)
plt.xlabel("Avg WH Temp")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X5, y1)
plt.xlabel("DP Choke Size")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X6, y1)
plt.xlabel("AVG_DOWNHOLE_PRESSURE")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X7, y1)
plt.xlabel("AVG_DOWNHOLE_TEMPERATURE  ")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X8, y1)
plt.xlabel("AVG_DP_TUBING")
plt.ylabel("Oil Volume")
plt.show()

# %% [markdown]
# ## NO 15/9-F-1 C

# %%
Well_F1 = production.loc[production['WELL_BORE_CODE']=='NO 15/9-F-1 C']
Well_F1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 746 entries, 0 to 745
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   746 non-null    object
#  1   WELL_BORE_CODE            746 non-null    object
#  2   AVG_DOWNHOLE_PRESSURE     743 non-null    float64
#  3   AVG_DOWNHOLE_TEMPERATURE  743 non-null    float64
#  4   AVG_DP_TUBING             743 non-null    float64
#  5   AVG_ANNULUS_PRESS         17 non-null     float64
#  6   AVG_CHOKE_SIZE_P          746 non-null    float64
#  7   AVG_WHP_P                 746 non-null    float64
#  8   AVG_WHT_P                 746 non-null    float64
#  9   DP_CHOKE_SIZE             746 non-null    float64
#  10  BORE_OIL_VOL              746 non-null    float64
#  11  BORE_GAS_VOL              746 non-null    float64
#  12  BORE_WAT_VOL              746 non-null    float64
# dtypes: float64(11), object(2)
# ...

# %%
Well_F1 =Well_F1.drop(Well_F1[(Well_F1['BORE_OIL_VOL'] == 0) & (Well_F1['BORE_GAS_VOL'] == 0.0) & (Well_F1['BORE_WAT_VOL'] == 0)].index)
Well_F1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 430 entries, 15 to 730
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   430 non-null    object
#  1   WELL_BORE_CODE            430 non-null    object
#  2   AVG_DOWNHOLE_PRESSURE     430 non-null    float64
#  3   AVG_DOWNHOLE_TEMPERATURE  430 non-null    float64
#  4   AVG_DP_TUBING             430 non-null    float64
#  5   AVG_ANNULUS_PRESS         1 non-null      float64
#  6   AVG_CHOKE_SIZE_P          430 non-null    float64
#  7   AVG_WHP_P                 430 non-null    float64
#  8   AVG_WHT_P                 430 non-null    float64
#  9   DP_CHOKE_SIZE             430 non-null    float64
#  10  BORE_OIL_VOL              430 non-null    float64
#  11  BORE_GAS_VOL              430 non-null    float64
#  12  BORE_WAT_VOL              430 non-null    float64
# dtypes: float64(11), object(2)
# ...

# %%
Well_F1.to_csv('F1.csv')

# %%
y1= Well_F1["BORE_OIL_VOL"].values.reshape(-1, 1)
# X1=Well_F1["AVG_ANNULUS_PRESS"].values.reshape(-1, 1)
X2=Well_F1["AVG_CHOKE_SIZE_P"].values.reshape(-1, 1)
X3=Well_F1["AVG_WHP_P"].values.reshape(-1, 1)
X4=Well_F1["AVG_WHT_P"].values.reshape(-1, 1)
X5=Well_F1["DP_CHOKE_SIZE"].values.reshape(-1, 1)
X6=Well_F1["AVG_DOWNHOLE_PRESSURE"].values.reshape(-1, 1)
X7=Well_F1["AVG_DOWNHOLE_TEMPERATURE"].values.reshape(-1, 1)
X8=Well_F1["AVG_DP_TUBING"].values.reshape(-1, 1)

# %%
# plt.scatter(X1, y1)
# plt.xlabel("AVG_ANNULUS_PRESS")
# plt.ylabel("Oil Volume")
# plt.show()

plt.scatter(X2, y1)
plt.xlabel("Avg Choke Size")
plt.ylabel("Oil Volume")
plt.show()


plt.scatter(X3, y1)
plt.xlabel("Avg WHP")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X4, y1)
plt.xlabel("Avg WH Temp")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X5, y1)
plt.xlabel("DP Choke Size")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X6, y1)
plt.xlabel("AVG_DOWNHOLE_PRESSURE")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X7, y1)
plt.xlabel("AVG_DOWNHOLE_TEMPERATURE  ")
plt.ylabel("Oil Volume")
plt.show()

plt.scatter(X8, y1)
plt.xlabel("AVG_DP_TUBING")
plt.ylabel("Oil Volume")
plt.show()
