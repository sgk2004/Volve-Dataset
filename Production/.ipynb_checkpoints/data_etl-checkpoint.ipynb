# %%
#Dependencies

import pandas as pd
import csv
import os

# %% [markdown]
# ## Data Extraction file 1

# %% [markdown]
# ## Volvo production data

# %%
production_df =pd.read_excel('Data/Volve production data_Edited.xlsx')
production_df
# Out:
#          DATEPRD  WELL_BORE_CODE  AVG_DOWNHOLE_PRESSURE  \
# 0     2014-04-07   NO 15/9-F-1 C                0.00000
# 1     2014-04-08   NO 15/9-F-1 C                    NaN
# 2     2014-04-09   NO 15/9-F-1 C                    NaN
# 3     2014-04-10   NO 15/9-F-1 C                    NaN
# 4     2014-04-11   NO 15/9-F-1 C              310.37614
# ...          ...             ...                    ...
# 15629 2016-09-14  NO 15/9-F-5 AH                    NaN
# 15630 2016-09-15  NO 15/9-F-5 AH                    NaN
# 15631 2016-09-16  NO 15/9-F-5 AH                    NaN
# 15632 2016-09-17  NO 15/9-F-5 AH                    NaN
# 15633 2016-09-18  NO 15/9-F-5 AH                    NaN
#
#        AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  AVG_CHOKE_SIZE_P  AVG_WHP_P  \
# 0                       0.00000        0.00000          0.000000    0.00000
# 1                           NaN            NaN          1.003059    0.00000
# ...

# %%
production_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15634 entries, 0 to 15633
# Data columns (total 12 columns):
# DATEPRD                     15634 non-null datetime64[ns]
# WELL_BORE_CODE              15634 non-null object
# AVG_DOWNHOLE_PRESSURE       8980 non-null float64
# AVG_DOWNHOLE_TEMPERATURE    8980 non-null float64
# AVG_DP_TUBING               8980 non-null float64
# AVG_CHOKE_SIZE_P            8919 non-null float64
# AVG_WHP_P                   9155 non-null float64
# AVG_WHT_P                   9146 non-null float64
# DP_CHOKE_SIZE               15340 non-null float64
# BORE_OIL_VOL                9161 non-null float64
# BORE_GAS_VOL                9161 non-null float64
# BORE_WAT_VOL                9161 non-null float64
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 1.4+ MB

# %%
production_df['WELL_BORE_CODE'].unique()
# Out:
# array(['NO 15/9-F-1 C', 'NO 15/9-F-11 H', 'NO 15/9-F-12 H',
#        'NO 15/9-F-14 H', 'NO 15/9-F-15 D', 'NO 15/9-F-4 AH',
#        'NO 15/9-F-5 AH'], dtype=object)

# %% [markdown]
# AVG_DOWNHOLE_PRESSURE Vs AVG_WHP_P
#
# AVG_DOWNHOLE_TEMPERATURE Vs AVG_WHT_P
#
#
# AVG_CHOKE_SIZE_P  8919 Vs AVG_WHP_P
#
# DP_CHOKE_SIZE Vs AVG_WHP_P
#
#
# AVG_DOWNHOLE_PRESSURE Vs BORE_OIL_VOL
#
# AVG_DOWNHOLE_PRESSURE Vs BORE_GAS_VOL
#
# AVG_DOWNHOLE_PRESSURE Vs BORE_WAT_VOL
#
#
# AVG_WHP_P VS BORE_OIL_VOL
#
# AVG_WHP_P Vs BORE_GAS_VOL
#
# AVG_WHP_P Vs BORE_WAT_VOL
#
#
# AVG_WHP_P Vs DP_CHOKE_SIZE

# %%
df=production_df.dropna(subset=['AVG_DOWNHOLE_PRESSURE', 'AVG_WHP_P', 'AVG_DOWNHOLE_TEMPERATURE','AVG_WHT_P'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8980 entries, 0 to 9000
# Data columns (total 12 columns):
# DATEPRD                     8980 non-null datetime64[ns]
# WELL_BORE_CODE              8980 non-null object
# AVG_DOWNHOLE_PRESSURE       8980 non-null float64
# AVG_DOWNHOLE_TEMPERATURE    8980 non-null float64
# AVG_DP_TUBING               8980 non-null float64
# AVG_CHOKE_SIZE_P            8740 non-null float64
# AVG_WHP_P                   8980 non-null float64
# AVG_WHT_P                   8980 non-null float64
# DP_CHOKE_SIZE               8980 non-null float64
# BORE_OIL_VOL                8980 non-null float64
# BORE_GAS_VOL                8980 non-null float64
# BORE_WAT_VOL                8980 non-null float64
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 912.0+ KB

# %%
df.to_csv('production_filtered.csv')
